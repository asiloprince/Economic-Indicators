# %% [markdown]
# # Importing all the libraries needed in the analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
#from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline

# %%
df = pd.read_csv('ds/economic_indicators.csv')[:-12]

# %%
df
# Out:
#          Country Name Country Code
# 0         Philippines          PHL  \
# 1         Philippines          PHL
# 2         Philippines          PHL
# 3         Philippines          PHL
# 4             Myanmar          MMR
# 5             Myanmar          MMR
# 6             Myanmar          MMR
# 7             Myanmar          MMR
# 8             Lao PDR          LAO
# 9             Lao PDR          LAO
# 10            Lao PDR          LAO
# 11            Lao PDR          LAO
# 12           Cambodia          KHM
# 13           Cambodia          KHM
# 14           Cambodia          KHM
# 15           Cambodia          KHM
# 16  Brunei Darussalam          BRN
# 17  Brunei Darussalam          BRN
# 18  Brunei Darussalam          BRN
# 19  Brunei Darussalam          BRN
# 20          Indonesia          IDN
# 21          Indonesia          IDN
# 22          Indonesia          IDN
# 23          Indonesia          IDN
# 24           Malaysia          MYS
# 25           Malaysia          MYS
# 26           Malaysia          MYS
# 27           Malaysia          MYS
# 28          Singapore          SGP
# 29          Singapore          SGP
# 30          Singapore          SGP
# 31          Singapore          SGP
# 32           Thailand          THA
# 33           Thailand          THA
# 34           Thailand          THA
# 35           Thailand          THA
# 36            Vietnam          VNM
# 37            Vietnam          VNM
# 38            Vietnam          VNM
# 39            Vietnam          VNM
#
#                                           Series Name        Series Code
# 0                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG  \
# 1                    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 2                                   Population, total        SP.POP.TOTL
# 3   Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 4                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 5                    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 6                                   Population, total        SP.POP.TOTL
# 7   Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 8                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 9                    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 10                                  Population, total        SP.POP.TOTL
# 11  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 12                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 13                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 14                                  Population, total        SP.POP.TOTL
# 15  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 16                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 17                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 18                                  Population, total        SP.POP.TOTL
# 19  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 20                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 21                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 22                                  Population, total        SP.POP.TOTL
# 23  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 24                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 25                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 26                                  Population, total        SP.POP.TOTL
# 27  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 28                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 29                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 30                                  Population, total        SP.POP.TOTL
# 31  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 32                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 33                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 34                                  Population, total        SP.POP.TOTL
# 35  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 36                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 37                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 38                                  Population, total        SP.POP.TOTL
# 39  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
#
#             2000          2001          2002          2003          2004
# 0   4.382505e+00  3.049232e+00  3.716255e+00  5.086911e+00  6.569229e+00  \
# 1   2.094019e+00  8.907429e-01  1.598835e+00  2.987190e+00  4.472465e+00
# 2   7.795822e+07  7.962609e+07  8.128557e+07  8.294284e+07  8.460750e+07
# 3   3.655000e+00  3.700000e+00  3.627000e+00  3.530000e+00  3.550000e+00
# 4   1.241819e+01  1.246773e+01  1.170305e+01  1.298632e+01  1.369529e+01
# 5   1.119202e+01  1.130310e+01  1.058457e+01  1.191709e+01  1.270059e+01
# 6   4.553833e+07  4.601483e+07  4.648023e+07  4.692429e+07  4.733845e+07
# 7   6.540000e-01  6.560000e-01  6.630000e-01  6.560000e-01  6.530000e-01
# 8   5.798782e+00  5.751413e+00  5.918744e+00  6.067002e+00  6.357695e+00
# 9   4.029960e+00  4.049070e+00  4.286461e+00  4.520220e+00  4.899155e+00
# 33  2.644813e+00  2.977158e+00  3.749844e+00  3.886440e+00  1.893854e+00
# 34  7.029440e+07  7.060704e+07  7.089820e+07  7.112780e+07  7.130776e+07
# 35  6.000000e-01  6.900000e-01  8.300000e-01  7.700000e-01  7.200000e-01
# 36  6.987167e+00  6.690009e+00  6.940188e+00  7.464991e+00  7.359281e+00
# 37  5.877862e+00  5.618680e+00  5.909238e+00  6.467176e+00  6.392604e+00
# 38  9.219140e+07  9.312653e+07  9.403305e+07  9.491433e+07  9.577672e+07
# 39  1.850000e+00  1.850000e+00  1.870000e+00  1.160000e+00  1.680000e+00
#
#             2020
# 0  -9.518295e+00
# 1  -1.097819e+01
# 2   1.121910e+08
# 3   2.520000e+00
# 4   3.173774e+00
# 5   2.434131e+00
# 6   5.342320e+07
# 7   1.480000e+00
# 8   5.030318e-01
# 9  -9.709414e-01
# 10  7.319399e+06
# 11  3.576000e+00
# 12 -3.096007e+00
# 13 -4.213654e+00
# 14  1.639686e+07
# 15  2.980000e-01
# 16  1.133573e+00
# 17  2.917189e-01
# 18  4.417250e+05
# 19  7.410000e+00
# 20 -2.065005e+00
# 21 -2.884591e+00
# 22  2.718580e+08
# 23  4.250000e+00
# 24 -5.534456e+00
# 25 -6.661137e+00
# 26  3.319999e+07
# 27  4.540000e+00
# 28 -4.143106e+00
# 29 -3.843656e+00
# 30  5.685807e+06
# 31  4.100000e+00
# 32 -6.195489e+00
# 33 -6.415842e+00
# 34  7.147566e+07
# 35  1.100000e+00
# 36  2.865412e+00
# 37  1.937355e+00
# 38  9.664868e+07
# 39  2.100000e+00
#
# [40 rows x 25 columns]

# %% [markdown]
# #  Philippines' Unemployment rate from 2000 to 2020

# %%
# Filter the data for the Philippines
ph_unemployment = df[(df['Country Name'] == 'Philippines') & (df['Series Code'] == 'SL.UEM.TOTL.ZS')]

years = ph_unemployment.columns[4:].tolist()
unemployment = ph_unemployment.values.flatten()[4:]

fig, ax = plt.subplots(figsize=(12, 6))  # Adjust the size (width, height)

# Plot the line chart
ax.plot(years, unemployment, marker='o', linestyle='-', color='b')

# Customize the plot
ax.set_xlabel('Year')
ax.set_ylabel('Unemployment (%)')
ax.set_title('Unemployment in the Philippines')
ax.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Comparing the unemployment rates across different countries in year 2020.

# %%
asean_countries = ['Indonesia', 'Malaysia', 'Philippines', 'Singapore', 'Thailand', 'Vietnam','Lao PDR','Brunei Darussalam','Myanmar','Cambodia']

# Filter the DataFrame for ASEAN member countries and unemployment data
asean_unemployment = df[df['Country Name'].isin(asean_countries) & (df['Series Code'] == 'SL.UEM.TOTL.ZS')]

# Iterate over the ASEAN countries and plot the unemployment data
fig, ax = plt.subplots(figsize=(12, 6))  # Adjust the size (width, height)

for country in asean_countries:
    country_data = asean_unemployment[asean_unemployment['Country Name'] == country]
    years = country_data.columns[4:].tolist()
    unemployment = country_data.values.flatten()[4:]
    ax.plot(years, unemployment, label=country)

# Customize the plot
ax.set_xlabel('Year')
ax.set_ylabel('Unemployment (%)')
ax.set_title('Unemployment in ASEAN Member Countries')
ax.legend()
ax.grid(True)

# Display the plot
plt.show()

# %%
unemployment = df[df['Series Code'] == 'SL.UEM.TOTL.ZS'].copy()
unemployment_df = unemployment.copy()
unemployment_df.reset_index(drop=True, inplace=True)

# %%
unemployment_df
# Out:
#         Country Name Country Code
# 0        Philippines          PHL  \
# 1            Myanmar          MMR
# 2            Lao PDR          LAO
# 3           Cambodia          KHM
# 4  Brunei Darussalam          BRN
# 5          Indonesia          IDN
# 6           Malaysia          MYS
# 7          Singapore          SGP
# 8           Thailand          THA
# 9            Vietnam          VNM
#
#                                          Series Name     Series Code   2000
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  3.655  \
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  0.654
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  2.040
# 3  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  0.972
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  5.597
# 5  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  6.080
# 6  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  3.000
# 7  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  3.700
# 8  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  2.390
# 9  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS  2.260
#
#     2001   2002   2003   2004   2005  ...   2011   2012   2013   2014   2015
# 0  3.700  3.627  3.530  3.550  3.800  ...  3.590  3.500  3.500  3.600  3.070  \
# 1  0.656  0.663  0.656  0.653  0.656  ...  0.719  0.731  0.722  0.723  0.770
# 2  1.913  1.778  1.642  1.503  1.350  ...  1.069  1.422  1.775  2.146  2.521
# 3  1.040  1.107  1.121  1.134  1.130  ...  0.580  0.509  0.440  0.690  0.390
# 4  5.694  5.810  5.891  5.946  6.040  ...  6.690  6.732  6.770  6.860  7.693
# 5  6.080  6.600  6.660  7.300  7.940  ...  5.150  4.470  4.340  4.050  4.510
# 6  3.530  3.480  3.610  3.540  3.530  ...  3.050  3.100  3.160  2.880  3.100
# 7  3.760  5.650  5.930  5.840  5.590  ...  3.890  3.720  3.860  3.740  3.790
# 8  2.600  1.820  1.540  1.510  1.350  ...  0.660  0.580  0.250  0.580  0.600
# 9  2.760  2.120  2.250  2.140  2.094  ...  1.000  1.030  1.320  1.260  1.850
#
#     2016  2017   2018   2019   2020
# 0  2.700  2.55  2.340  2.240  2.520
# 1  0.994  1.36  0.770  0.410  1.480
# 2  2.896  3.27  3.266  3.273  3.576
# 3  0.720  0.14  0.142  0.146  0.298
# 4  8.432  9.32  8.700  6.920  7.410
# 5  4.300  3.78  4.390  3.590  4.250
# 6  3.440  3.41  3.300  3.260  4.540
# 7  4.080  4.20  3.641  3.100  4.100
# 8  0.690  0.83  0.770  0.720  1.100
# 9  1.850  1.87  1.160  1.680  2.100
#
# [10 rows x 25 columns]

# %% [markdown]
# # Highlight variations in unemployment rates across countries and years

# %%
data_heatmap = unemployment_df.iloc[:, 4:]

# figure size
plt.figure(figsize=(14, 6))

# Create the heatmap
sns.heatmap(data_heatmap, cmap='YlGnBu')

# Set the title and labels
plt.title('Unemployment Rates Heatmap')
plt.xlabel('Year')
plt.ylabel('Country')

# Display the heatmap
plt.show()

# %%
data_2020 = unemployment_df['2020']

# Set the country as the x-axis labels
countries = unemployment_df['Country Name']

# Plotting bar chart
plt.figure(figsize=(10, 5))  # size (w,h)
plt.bar(countries, data_2020)

# title and labels
plt.title('Unemployment Rates in 2020')
plt.xlabel('Country')
plt.ylabel('Unemployment Rate')

# for better readability/ vertical
plt.xticks(rotation=90)

plt.show()

# %%
df
